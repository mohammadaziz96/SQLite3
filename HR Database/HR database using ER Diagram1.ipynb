# %%
#In this Exercise i'm going to use "HR" database using ER Diagram

# %%
import sqlite3
import pandas as pd

# %%
connection=sqlite3.connect("hr")

# %%
crsr=connection.cursor()

# %%
crsr.execute("select REGION_ID from regions")

# %%
crsr.fetchall()
# Out:
# [(1,), (2,), (3,), (4,), (999,), ('REGION_ID',)]

# %% [markdown]
# # Exercises![Screenshot%20from%202021-10-07%2018-32-02.png](attachment:Screenshot%20from%202021-10-07%2018-32-02.png)

# %%
#1 Write a query to display the names (first_name, last_name) using alias name "First Name", "Last Name"

# %%
crsr.execute("select first_name as First_Name, last_name as Last_Name from employees")

# %%
crsr.fetchall()
# Out:
# [('Steven', 'King'),
#  ('Neena', 'Kochhar'),
#  ('Lex', 'De Haan'),
#  ('Alexander', 'Hunold'),
#  ('Bruce', 'Ernst'),
#  ('David', 'Austin'),
#  ('Valli', 'Pataballa'),
#  ('Diana', 'Lorentz'),
#  ('Nancy', 'Greenberg'),
#  ('Daniel', 'Faviet'),
#  ('John', 'Chen'),
#  ('Ismael', 'Sciarra'),
#  ('Jose Manuel', 'Urman'),
#  ('Luis', 'Popp'),
#  ('Den', 'Raphaely'),
#  ('Alexander', 'Khoo'),
#  ('Shelli', 'Baida'),
#  ('Sigal', 'Tobias'),
#  ('Guy', 'Himuro'),
#  ('Karen', 'Colmenares'),
#  ('Matthew', 'Weiss'),
#  ('Adam', 'Fripp'),
#  ('Payam', 'Kaufling'),
#  ('Shanta', 'Vollman'),
#  ('Kevin', 'Mourgos'),
#  ('Julia', 'Nayer'),
#  ('Irene', 'Mikkilineni'),
#  ('James', 'Landry'),
#  ('Steven', 'Markle'),
#  ('Laura', 'Bissot'),
#  ('Mozhe', 'Atkinson'),
#  ('James', 'Marlow'),
#  ('TJ', 'Olson'),
#  ('Jason', 'Mallin'),
#  ('Michael', 'Rogers'),
#  ('Ki', 'Gee'),
#  ('Hazel', 'Philtanker'),
#  ('Renske', 'Ladwig'),
#  ('Stephen', 'Stiles'),
#  ('John', 'Seo'),
# ...

# %%
df1=pd.read_sql("select first_name as 'First Name', last_name as 'Last Name' from employees", connection)
df1.head(10)
# Out:
#   First Name  Last Name
# 0     Steven       King
# 1      Neena    Kochhar
# 2        Lex    De Haan
# 3  Alexander     Hunold
# 4      Bruce      Ernst
# 5      David     Austin
# 6      Valli  Pataballa
# 7      Diana    Lorentz
# 8      Nancy  Greenberg
# 9     Daniel     Faviet

# %%
#2 Write a query to get unique department ID from employee table.

# %%
df2=pd.read_sql("select distinct department_id from employees", connection)
df2
# Out:
#     department_id
# 0              90
# 1              60
# 2             100
# 3              30
# 4              50
# 5              80
# 6               0
# 7              10
# 8              20
# 9              40
# 10             70
# 11            110

# %%
#3 Write a query to get all employee details from the employee table order by first name, descending.

# %%
df3=pd.read_sql("select * from employees order by first_name desc", connection)
df3.head(10)
# Out:
#    employee_id first_name  last_name     email        phone_number  \
# 0          180    Winston     Taylor   WTAYLOR        650.507.9876
# 1          171    William      Smith    WSMITH  011.44.1343.629268
# 2          206    William      Gietz    WGIETZ        515.123.8181
# 3          195      Vance      Jones    VJONES        650.501.4876
# 4          106      Valli  Pataballa  VPATABAL        590.423.4560
# 5          141     Trenna       Rajs     TRAJS        650.121.8009
# 6          190    Timothy      Gates    TGATES        650.505.3876
# 7          170     Tayler        Fox      TFOX  011.44.1343.729268
# 8          132         TJ      Olson   TJOLSON        650.124.8234
# 9          203      Susan     Mavris   SMAVRIS        515.123.7777
#
#     hire_date      job_id  salary  commission_pct  manager_id  department_id  \
# 0  1987-09-05    SH_CLERK    3200            0.00         120             50
# ...

# %%
#4 Write a query to get the names (first_name, last_name), salary, PF of all the employees (PF is calculated as 12% of salary).

# %%
df4=pd.read_sql("select first_name, last_name, salary, ((salary*12)/100) as PF from employees", connection)
df4.head(10)
# Out:
#   first_name  last_name  salary    PF
# 0     Steven       King   24000  2880
# 1      Neena    Kochhar   17000  2040
# 2        Lex    De Haan   17000  2040
# 3  Alexander     Hunold    9000  1080
# 4      Bruce      Ernst    6000   720
# 5      David     Austin    4800   576
# 6      Valli  Pataballa    4800   576
# 7      Diana    Lorentz    4200   504
# 8      Nancy  Greenberg   12000  1440
# 9     Daniel     Faviet    9000  1080

# %%
#5 Write a query to get the employee ID, names (first_name, last_name), salary in ascending order of salary.

# %%
df5=pd.read_sql("select employee_id, first_name|| ' ' ||last_name as Name, salary from employees order by salary asc", connection)
df5.head(15)
# Out:
#     employee_id              Name  salary
# 0           132          TJ Olson    2100
# 1           128     Steven Markle    2200
# 2           136  Hazel Philtanker    2200
# 3           127      James Landry    2400
# 4           135            Ki Gee    2400
# 5           119  Karen Colmenares    2500
# 6           131      James Marlow    2500
# 7           140      Joshua Patel    2500
# 8           144      Peter Vargas    2500
# 9           182   Martha Sullivan    2500
# 10          191   Randall Perkins    2500
# 11          118        Guy Himuro    2600
# 12          143     Randall Matos    2600
# 13          198   Donald OConnell    2600
# 14          199     Douglas Grant    2600

# %%
#6 Write a query to get the total salaries payable to employees.

# %%
df6=pd.read_sql("select sum(salary) from employees", connection)
df6
# Out:
#    sum(salary)
# 0       691400

# %%
#7 Write a query to get the maximum and minimum salary from employees table.

# %%
df7=pd.read_sql("select max(salary), min(salary) from employees", connection)
df7
# Out:
#    max(salary)  min(salary)
# 0        24000         2100

# %%
#8 Write a query to get the average salary and number of employees in the employees table.

# %%
df8=pd.read_sql("select avg(salary), count(*) from employees", connection)
df8
# Out:
#    avg(salary)  count(*)
# 0  6461.682243       107

# %%
#9 Write a query to get the number of employees working with the company.

# %%
df9=pd.read_sql("select count(*) from employees", connection)
df9
# Out:
#    count(*)
# 0       107

# %%
#10 Write a query to get the number of jobs available in the employees table.

# %%
df10=pd.read_sql("select count(distinct job_id) from employees", connection)
df10
# Out:
#    count(distinct job_id)
# 0                      19

# %%
#11 Write a query get all first name from employees table in upper case.

# %%
df11=pd.read_sql("select upper(first_name) from employees", connection)
df11.head(10)
# Out:
#   upper(first_name)
# 0            STEVEN
# 1             NEENA
# 2               LEX
# 3         ALEXANDER
# 4             BRUCE
# 5             DAVID
# 6             VALLI
# 7             DIANA
# 8             NANCY
# 9            DANIEL

# %%
#12 Write a query to get the first 3 characters of first name from employees table.

# %%
df12=pd.read_sql("select substr(first_name,1,3) from employees", connection)
df12.head(10)
# Out:
#   substr(first_name,1,3)
# 0                    Ste
# 1                    Nee
# 2                    Lex
# 3                    Ale
# 4                    Bru
# 5                    Dav
# 6                    Val
# 7                    Dia
# 8                    Nan
# 9                    Dan

# %%
#13 Write a query to calculate 171*214+625.

# %%
df13=pd.read_sql("select 171*214+625 result", connection)
df13
# Out:
#    result
# 0   37219

# %%
#14 Write a query to get the names (for example Ellen Abel, Sundar Ande etc.) of all the employees from employees table.

# %%
df14=pd.read_sql("select first_name || ' ' || last_name as 'Employee Name' from employees", connection)
df14.head(10)
# Out:
#       Employee Name
# 0       Steven King
# 1     Neena Kochhar
# 2       Lex De Haan
# 3  Alexander Hunold
# 4       Bruce Ernst
# 5      David Austin
# 6   Valli Pataballa
# 7     Diana Lorentz
# 8   Nancy Greenberg
# 9     Daniel Faviet

# %%
#15 Write a query to get first name from employees table after removing white spaces from both side.

# %%
df15=pd.read_sql("select trim(first_name) from employees", connection)
df15.head(10)
# Out:
#   trim(first_name)
# 0           Steven
# 1            Neena
# 2              Lex
# 3        Alexander
# 4            Bruce
# 5            David
# 6            Valli
# 7            Diana
# 8            Nancy
# 9           Daniel

# %%
#16 Write a query to get the length of the employee names (first_name, last_name) from employees table.

# %%
df16=pd.read_sql("select first_name, last_name, length(first_name)+length(last_name) as 'Length of name' from employees", connection)
df16.head(10)
# Out:
#   first_name  last_name  Length of name
# 0     Steven       King              10
# 1      Neena    Kochhar              12
# 2        Lex    De Haan              10
# 3  Alexander     Hunold              15
# 4      Bruce      Ernst              10
# 5      David     Austin              11
# 6      Valli  Pataballa              14
# 7      Diana    Lorentz              12
# 8      Nancy  Greenberg              14
# 9     Daniel     Faviet              12

# %%
#17 Write a query to select first 10 records from a table.

# %%
df17=pd.read_sql("select * from employees limit 10", connection)
df17
# Out:
#    employee_id first_name  last_name     email  phone_number   hire_date  \
# 0          100     Steven       King     SKING  515.123.4567  1987-06-17
# 1          101      Neena    Kochhar  NKOCHHAR  515.123.4568  1987-06-18
# 2          102        Lex    De Haan   LDEHAAN  515.123.4569  1987-06-19
# 3          103  Alexander     Hunold   AHUNOLD  590.423.4567  1987-06-20
# 4          104      Bruce      Ernst    BERNST  590.423.4568  1987-06-21
# 5          105      David     Austin   DAUSTIN  590.423.4569  1987-06-22
# 6          106      Valli  Pataballa  VPATABAL  590.423.4560  1987-06-23
# 7          107      Diana    Lorentz  DLORENTZ  590.423.5567  1987-06-24
# 8          108      Nancy  Greenberg  NGREENBE  515.124.4569  1987-06-25
# 9          109     Daniel     Faviet   DFAVIET  515.124.4169  1987-06-26
#
#        job_id  salary  commission_pct  manager_id  department_id Avg_Salary
# 0     AD_PRES   24000               0           0             90       None
# ...

# %%
#18 Write a query to get monthly salary (round 2 decimal places) of each and every employee?

# %%
df18=pd.read_sql("select round(salary/12, 2) as 'Monthly Salary' from employees", connection)
df18.head(10)
# Out:
#    Monthly Salary
# 0          2000.0
# 1          1416.0
# 2          1416.0
# 3           750.0
# 4           500.0
# 5           400.0
# 6           400.0
# 7           350.0
# 8          1000.0
# 9           750.0
